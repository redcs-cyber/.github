# %% [markdown]
# <a href="https://colab.research.google.com/github/redcs-cyber/.github/blob/main/DeepSeek_R1_Zero_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers # Commented out to prevent upgrading transformers to an incompatible version

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/deepseek-ai/DeepSeek-R1-Zero
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/deepseek-ai/DeepSeek-R1-Zero)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# @title
import subprocess
import sys

print("Attempting to install compatible tokenizers and transformers versions...")

# First, install a compatible tokenizers version with wheels for Python 3.12
print("Installing tokenizers==0.15.2...")
process_tokenizers = subprocess.run([sys.executable, "-m", "pip", "install", "tokenizers==0.15.2", "--force-reinstall"], capture_output=True, text=True)
print("pip tokenizers stdout:", process_tokenizers.stdout)
print("pip tokenizers stderr:", process_tokenizers.stderr)
if process_tokenizers.returncode != 0:
    print(f"Error during tokenizers installation: {process_tokenizers.returncode}")
    print("Please check the error messages above. A manual fix might be needed for tokenizers.")
else:
    print("tokenizers installed successfully.")

# Then, install a compatible transformers version
print("Installing transformers==4.35.0...")
process_transformers = subprocess.run([sys.executable, "-m", "pip", "install", "transformers==4.35.0", "--force-reinstall"], capture_output=True, text=True)
print("pip transformers stdout:", process_transformers.stdout)
print("pip transformers stderr:", process_transformers.stderr)
if process_transformers.returncode != 0:
    print(f"Error during transformers installation: {process_transformers.returncode}")
    print("Please check the error messages above. A manual fix might be needed for transformers.")
else:
    print("transformers installed successfully.")

# Verify the installed versions
print("Verifying transformers version...")
process_version_transformers = subprocess.run([sys.executable, "-m", "pip", "show", "transformers"], capture_output=True, text=True)
print("pip show transformers output:\n", process_version_transformers.stdout)

print("Verifying tokenizers version...")
process_version_tokenizers = subprocess.run([sys.executable, "-m", "pip", "show", "tokenizers"], capture_output=True, text=True)
print("pip show tokenizers output:\n", process_version_tokenizers.stdout)
# Out:
# Attempting to install compatible tokenizers and transformers versions...
# Installing tokenizers==0.15.2...
# pip tokenizers stdout: Collecting tokenizers==0.15.2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 89.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 40.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 80.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 39.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# Add `%load_ext cudf.pandas` before importing pandas to speed up operations using GPU

# %% [markdown]
# Add `%load_ext cuml.accel` before importing sklearn to speed up operations using GPU

# %% [markdown]
# Add `%load_ext cuml.accel` before importing sklearn to speed up operations using GPU

# %% [markdown]
# Add `%load_ext cuml.accel` before importing sklearn to speed up operations using GPU

# %% [markdown]
# Add `%load_ext cuml.accel` before importing sklearn to speed up operations using GPU

# %% [markdown]
# Add `%load_ext cuml.accel` before importing sklearn to speed up operations using GPU

# %% [markdown]
# Add `%load_ext cuml.accel` before importing sklearn to speed up operations using GPU

# %% [markdown]
# Add `%load_ext cudf.pandas` before importing pandas to speed up operations using GPU

# %%
# %load_ext cudf.pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Randomly generated dataset of parking violations-
# Define the number of rows
num_rows = 1000000

states = ["NY", "NJ", "CA", "TX"]
violations = ["Double Parking", "Expired Meter", "No Parking",
              "Fire Hydrant", "Bus Stop"]
vehicle_types = ["SUBN", "SDN"]

# Create a date range
start_date = "2022-01-01"
end_date = "2022-12-31"
dates = pd.date_range(start=start_date, end=end_date, freq='D')

# Generate random data
data = {
    "Registration State": np.random.choice(states, size=num_rows),
    "Violation Description": np.random.choice(violations, size=num_rows),
    "Vehicle Body Type": np.random.choice(vehicle_types, size=num_rows),
    "Issue Date": np.random.choice(dates, size=num_rows),
    "Ticket Number": np.random.randint(1000000000, 9999999999, size=num_rows)
}

# Create a DataFrame
df = pd.DataFrame(data)

# How does the parking violations change from day to day segmented by vehicle type
# Averaged using a 7-day rolling mean

daily_counts = df.groupby(['Issue Date', 'Vehicle Body Type']
                          ).size().unstack(fill_value=0)

# Calculate a 7-day rolling mean of daily violations for each vehicle type
rolling_means = daily_counts.rolling(window=7).mean()

# Display the rolling means for each vehicle type over time
rolling_means.tail(100).plot(figsize=(14, 7),
                             title="7-Day Rolling Average of Parking Violations by Vehicle Type")
plt.ylabel("Average Number of Violations")
plt.xlabel("Date")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/cudf/pandas/fast_slow_proxy.py in _fast_slow_function_call(func, transfer_block, *args, **kwargs)
#    1119         ):
# -> 1120             fast_args, fast_kwargs = _fast_arg(args), _fast_arg(kwargs)
#    1121             result = func(*fast_args, **fast_kwargs)
#
# /usr/local/lib/python3.12/dist-packages/cudf/pandas/fast_slow_proxy.py in _fast_arg(arg)
#    1313     seen: set[int] = set()
# -> 1314     return _transform_arg(arg, "_fsproxy_fast", seen)
#    1315
#
# /usr/local/lib/python3.12/dist-packages/cudf/pandas/fast_slow_proxy.py in _transform_arg(arg, attribute_name, seen)
#    1236             else:
# -> 1237                 return tuple(
#    1238                     _transform_arg(a, attribute_name, seen) for a in arg
#
# ...

# %% [markdown]
# Add `%load_ext cudf.pandas` before importing pandas to speed up operations using GPU

# %% [markdown]
# Add `%load_ext cudf.pandas` before importing pandas to speed up operations using GPU

# %%
# %load_ext cudf.pandas
import pandas as pd
import numpy as np

# Randomly generated dataset of parking violations-
# Define the number of rows
num_rows = 1000000

states = ["NY", "NJ", "CA", "TX"]
violations = ["Double Parking", "Expired Meter", "No Parking",
              "Fire Hydrant", "Bus Stop"]
vehicle_types = ["SUBN", "SDN"]

# Create a date range
start_date = "2022-01-01"
end_date = "2022-12-31"
dates = pd.date_range(start=start_date, end=end_date, freq='D')

# Generate random data
data = {
    "Registration State": np.random.choice(states, size=num_rows),
    "Violation Description": np.random.choice(violations, size=num_rows),
    "Vehicle Body Type": np.random.choice(vehicle_types, size=num_rows),
    "Issue Date": np.random.choice(dates, size=num_rows),
    "Ticket Number": np.random.randint(1000000000, 9999999999, size=num_rows)
}

# Create a DataFrame
df = pd.DataFrame(data)

# Which parking violation is most commonly committed by vehicles from various U.S states?

(df[["Registration State", "Violation Description"]]  # get only these two columns
 .value_counts()  # get the count of offences per state and per type of offence
 .groupby("Registration State")  # group by state
 .head(1)  # get the first row in each group (the type of offence with the largest count)
 .sort_index()  # sort by state name
 .reset_index()
)

# %%
# %load_ext cudf.pandas
import pandas as pd
import numpy as np

import pandas as pd
import numpy as np

# Define the number of rows
num_rows = 1000000

# Define the possible values
states = ["NY", "NJ", "CA", "TX"]
violations = ["Double Parking", "Expired Meter", "No Parking", "Fire Hydrant", "Bus Stop"]
vehicle_types = ["SUBN", "SDN"]

start_date = "2022-01-01"
end_date = "2022-12-31"
# Create a date range
dates = pd.date_range(start=start_date, end=end_date, freq='D')

# Generate random data
data = {
    "Registration State": np.random.choice(states, size=num_rows),
    "Violation Description": np.random.choice(violations, size=num_rows),
    "Vehicle Body Type": np.random.choice(vehicle_types, size=num_rows),
    "Issue Date": np.random.choice(dates, size=num_rows),
    "Ticket Number": np.random.randint(1000000000, 9999999999, size=num_rows)
}

# Create a DataFrame
df = pd.DataFrame(data)

# Adding issue weekday based on the "Issue Date"
weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

# Grouping by issue_weekday and counting the Summons Number
df.groupby(["Issue Date"])["Ticket Number"
].count().sort_values()

# %%
# %load_ext cudf.pandas
import pandas as pd
import random

# Define the species categories
species_categories = ['setosa', 'versicolor', 'virginica']
flower_color_categories = ['red','yellow','green']

# Define the range for each attribute based on typical iris flower measurements
sepal_length_range = (4.0, 8.0)

# Create data for 1,000,000 samples
n = 1000000
data = {
    'sepal_length': [random.uniform(*sepal_length_range) for _ in range(n)],
    'flower_color': [random.choice(flower_color_categories) for _ in range(n)],
    'species': [random.choice(species_categories) for _ in range(n)]
}

df = pd.DataFrame(data)

df.groupby(['species','flower_color']).size().sort_values(ascending=False)

# %%
# %load_ext cuml.accel
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score

n_samples = 1000
n_features = 2
n_clusters = 3
X, _ = make_blobs(n_samples=n_samples, n_features=n_features, centers=n_clusters, random_state=42)

kmeans = KMeans(n_clusters=n_clusters, max_iter=100)
kmeans.fit(X)

labels = kmeans.labels_
print(silhouette_score(X, labels))

# %%
# %load_ext cuml.accel
import hdbscan
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score

n_samples = 1000
n_features = 2
n_clusters = 3
X, _ = make_blobs(n_samples=n_samples, n_features=n_features, centers=n_clusters, random_state=42)

clus = hdbscan.HDBSCAN()
clus.fit(X)

print(silhouette_score(X, clus.labels_))

# %%
# %load_ext cuml.accel
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier

X, y = make_classification(n_samples=100000, n_features=100, random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)
print(classification_report(y_test, y_pred))

# %%
# %load_ext cuml.accel
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X, y = make_classification(n_samples=1000000, n_features=200, random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

clf = LogisticRegression()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))

# %%
# %load_ext cuml.accel
import numpy as np
from sklearn.decomposition import PCA

X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
pca = PCA(n_components=2)
pca.fit(X)

print(pca.explained_variance_ratio_)
print(pca.singular_values_)

# %%
# %load_ext cuml.accel
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

X, y = make_classification(n_samples=100000, n_features=100, random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

clf = RandomForestClassifier(n_estimators=100, max_depth=5, max_features=1.0, n_jobs=-1)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))

# %%
# %load_ext cudf.pandas
import pandas as pd
import numpy as np

# Randomly generated dataset of parking violations-
# Define the number of rows
num_rows = 1000000

states = ["NY", "NJ", "CA", "TX"]
violations = ["Double Parking", "Expired Meter", "No Parking",
              "Fire Hydrant", "Bus Stop"]
vehicle_types = ["SUBN", "SDN"]

# Create a date range
start_date = "2022-01-01"
end_date = "2022-12-31"
dates = pd.date_range(start=start_date, end=end_date, freq='D')

# Generate random data
data = {
    "Registration State": np.random.choice(states, size=num_rows),
    "Violation Description": np.random.choice(violations, size=num_rows),
    "Vehicle Body Type": np.random.choice(vehicle_types, size=num_rows),
    "Issue Date": np.random.choice(dates, size=num_rows),
    "Ticket Number": np.random.randint(1000000000, 9999999999, size=num_rows)
}

# Create a DataFrame
df = pd.DataFrame(data)

# Which parking violation is most commonly committed by vehicles from various U.S states?

(df[["Registration State", "Violation Description"]]  # get only these two columns
 .value_counts()  # get the count of offences per state and per type of offence
 .groupby("Registration State")  # group by state
 .head(1)  # get the first row in each group (the type of offence with the largest count)
 .sort_index()  # sort by state name
 .reset_index()
)

# %%
import transformers.utils.import_utils

# Workaround: Add a dummy is_torch_fx_available if it's missing
# This function was removed in newer transformers versions but some remote code might still expect it.
if not hasattr(transformers.utils.import_utils, 'is_torch_fx_available'):
    def is_torch_fx_available():
        return False
    transformers.utils.import_utils.is_torch_fx_available = is_torch_fx_available

# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="deepseek-ai/DeepSeek-R1-Zero", trust_remote_code=True)
messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe(messages)

# %%
# @title 🚔 Parking Violations Analytics Dashboard {display-mode: "form"}
import json
import pandas as pd
from IPython.display import HTML
from google.colab import output

def _report_js_error(message):
    print(f"JavaScript Error: {message}")

output.register_callback('report_js_error', _report_js_error)

# Prepare data from the existing 'df' variable
# 1. KPIs
total_violations = len(df)
unique_states = df['Registration State'].nunique()
most_common_violation = df['Violation Description'].mode()[0]

# 2. Violations by State (Bar Chart)
state_counts = df['Registration State'].value_counts().to_dict()

# 3. Vehicle Type Distribution (Pie Chart)
vehicle_counts = df['Vehicle Body Type'].value_counts().to_dict()

# 4. Violations over time (Line Chart - grouped by month for better visibility)
df['Month'] = df['Issue Date'].dt.strftime('%Y-%m')
time_counts = df.groupby('Month').size().to_dict()

dashboard_data = {
    "kpis": {
        "total": f"{total_violations:,}",
        "states": unique_states,
        "top_violation": most_common_violation
    },
    "state_data": state_counts,
    "vehicle_data": vehicle_counts,
    "time_data": time_counts
}

html_content = """
<!DOCTYPE html>
<html lang='en'>
<head>
    <script src='https://cdn.jsdelivr.net/npm/chart.js'></script>
    <style>
        body { font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #f4f6f8; margin: 0; padding: 20px; }
        .dashboard-container { display: grid; grid-template-columns: repeat(4, 1fr); grid-gap: 20px; }
        .card { background: white; padding: 20px; border-radius: 12px; box-shadow: 0 4px 6px rgba(0,0,0,0.05); }
        .kpi-card { text-align: center; }
        .kpi-value { font-size: 2.5rem; font-weight: bold; color: #2c3e50; margin: 10px 0; }
        .kpi-label { font-size: 0.9rem; color: #7f8c8d; text-transform: uppercase; letter-spacing: 1px; }
        .chart-section { grid-column: span 2; display: flex; flex-direction: column; min-height: 400px; }
        .wide-chart { grid-column: span 4; min-height: 350px; }
        .canvas-wrapper { position: relative; flex-grow: 1; min-height: 0; }
        h2 { font-size: 1.2rem; color: #34495e; margin-bottom: 15px; }
    </style>
</head>
<body>
    <div class='dashboard-container'>
        <!-- KPI Row -->
        <div class='card kpi-card'>
            <div class='kpi-label'>Total Violations</div>
            <div class='kpi-value' id='total-kpi'>0</div>
        </div>
        <div class='card kpi-card'>
            <div class='kpi-label'>Unique States</div>
            <div class='kpi-value' id='states-kpi'>0</div>
        </div>
        <div class='card kpi-card' style='grid-column: span 2;'>
            <div class='kpi-label'>Most Frequent Violation</div>
            <div class='kpi-value' id='top-violation-kpi'>-</div>
        </div>

        <!-- Middle Row -->
        <div class='card chart-section'>
            <h2>Violations by Registration State</h2>
            <div class='canvas-wrapper'><canvas id='stateChart'></canvas></div>
        </div>
        <div class='card chart-section'>
            <h2>Vehicle Body Type Distribution</h2>
            <div class='canvas-wrapper'><canvas id='vehicleChart'></canvas></div>
        </div>

        <!-- Bottom Row -->
        <div class='card wide-chart'>
            <h2>Violations Trend (Monthly)</h2>
            <div class='canvas-wrapper'><canvas id='timeChart'></canvas></div>
        </div>
    </div>

    <script>
        window.onerror = function(message) {
            google.colab.kernel.invokeFunction('report_js_error', [message], {});
        };

        const rawData = DATA_PLACEHOLDER;

        // Update KPIs
        document.getElementById('total-kpi').innerText = rawData.kpis.total;
        document.getElementById('states-kpi').innerText = rawData.kpis.states;
        document.getElementById('top-violation-kpi').innerText = rawData.kpis.top_violation;

        // Charts Configuration
        const chartOptions = { responsive: true, maintainAspectRatio: false, plugins: { legend: { position: 'bottom' } } };

        // State Bar Chart
        new Chart(document.getElementById('stateChart'), {
            type: 'bar',
            data: {
                labels: Object.keys(rawData.state_data),
                datasets: [{ label: 'Violations', data: Object.values(rawData.state_data), backgroundColor: '#3498db' }]
            },
            options: chartOptions
        });

        // Vehicle Pie Chart
        new Chart(document.getElementById('vehicleChart'), {
            type: 'doughnut',
            data: {
                labels: Object.keys(rawData.vehicle_data),
                datasets: [{ data: Object.values(rawData.vehicle_data), backgroundColor: ['#e74c3c', '#f1c40f', '#2ecc71'] }]
            },
            options: chartOptions
        });

        // Time Line Chart
        const sortedMonths = Object.keys(rawData.time_data).sort();
        new Chart(document.getElementById('timeChart'), {
            type: 'line',
            data: {
                labels: sortedMonths,
                datasets: [{
                    label: 'Monthly Total',
                    data: sortedMonths.map(m => rawData.time_data[m]),
                    borderColor: '#9b59b6',
                    tension: 0.3,
                    fill: true,
                    backgroundColor: 'rgba(155, 89, 182, 0.1)'
                }]
            },
            options: chartOptions
        });
    </script>
</body>
</html>
""".replace('DATA_PLACEHOLDER', json.dumps(dashboard_data))

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang='en'>
# <head>
#     <script src='https://cdn.jsdelivr.net/npm/chart.js'></script>
#     <style>
#         body { font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #f4f6f8; margin: 0; padding: 20px; }
#         .dashboard-container { display: grid; grid-template-columns: repeat(4, 1fr); grid-gap: 20px; }
#         .card { background: white; padding: 20px; border-radius: 12px; box-shadow: 0 4px 6px rgba(0,0,0,0.05); }
#         .kpi-card { text-align: center; }
#         .kpi-value { font-size: 2.5rem; font-weight: bold; color: #2c3e50; margin: 10px 0; }
#         .kpi-label { font-size: 0.9rem; color: #7f8c8d; text-transform: uppercase; letter-spacing: 1px; }
#         .chart-section { grid-column: span 2; display: flex; flex-direction: column; min-height: 400px; }
#         .wide-chart { grid-column: span 4; min-height: 350px; }
#         .canvas-wrapper { position: relative; flex-grow: 1; min-height: 0; }
# ...
